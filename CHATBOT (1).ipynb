# %%
def chatbot():
    print("Chatbot: Type 'bye' to exit")

    while True:
        user = input("You: ").lower().strip()
        if user in ["hello", "hi", "hey", "hlo"]:
            print("Bot: Hello! How can I help you?")
        elif user in ["what is your name", "your name", "who are you"]:
            print("Bot: I'm your simple Python chatbot!")
        elif user in ["my name is", "i am", "i'm"]:
            print("Bot: Nice to meet you!")
        elif user in ["how are you", "how r u", "how are you doing"]:
            print("Bot: I'm doing great! Hope you're doing well too.")
        elif user in ["thanks", "thank you", "thnx"]:
            print("Bot: You're welcome!")
        elif user in ["tell me joke", "joke", "make me laugh"]:
            print("Bot: Why don’t programmers like nature? Too many bugs!")
        elif user in ["time", "what is the time"]:
            import datetime
            now = datetime.datetime.now().strftime("%H:%M:%S")
            print("Bot: The current time is:", now)
        elif user in ["date", "today date", "what is the date"]:
            import datetime
            today = datetime.date.today()
            print("Bot: Today's date is:", today)
        elif user in ["weather", "how is the weather", "today weather"]:
            print("Bot: I can't check real weather, but I hope it's sunny where you are!")
        elif user == "bye":
            print("Bot: ok bye! Have a nice day 🙂")
            break
        else:
            print("Bot: Sorry, I didn't understand that.")

chatbot()
# Out:
# Chatbot: Type 'bye' to exit
# You:  hi
# Bot: Hello! How can I help you?
# You:  what is your name
# Bot: I'm your simple Python chatbot!
# You:  what is the date
# Bot: Today's date is: 2025-11-27
# You:  what is the time
# Bot: The current time is: 10:12:52
# You:  bye
# Bot: Goodbye! Have a nice day 🙂
